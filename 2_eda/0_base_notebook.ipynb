# %% [markdown]
# # Template Notebook
# Notebook template with the stucture of the notebook and some default codes

# %% [markdown]
# ## Root folder and read env variables

# %%
import os
# fix root path to save outputs
actual_path = os.path.abspath(os.getcwd())
list_root_path = actual_path.split('\\')[:-1]
root_path = '\\'.join(list_root_path)
os.chdir(root_path)
print('root path: ', root_path)
# Out:
# root path:  D:\github-mi-repo\Optimization-Industrial-Process

# %%
import os
from dotenv import load_dotenv, find_dotenv # package used in jupyter notebook to read the variables in file .env

""" get env variable from .env """
load_dotenv(find_dotenv())

""" Read env variables and save it as python variable """
PROJECT_GCP = os.environ.get("PROJECT_GCP", "")

# %% [markdown]
# ## RUN

# %%
import pandas as pd
import numpy as np
from google.cloud import bigquery
import gcsfs
import pickle

# %%
### desarrollo

PROJECT_ID = PROJECT_GCP
! gcloud config set project $PROJECT_ID
# Out:
# Updated property [core/project].

# %% [markdown]
# ### 1. Read data

# %%
path_data = 'artifacts/data/data.pkl'
data = pd.read_pickle(path_data)
data.head()
# Out:
# Tag                  230AIT446.PNT_real  230AIT446.PNT_visto  \
# datetime
# 2021-01-01 00:05:00           11.555040            11.555040
# 2021-01-01 00:10:00           11.552320            11.552320
# 2021-01-01 00:15:00           11.549955            11.549955
# 2021-01-01 00:20:00           11.547145            11.547145
# 2021-01-01 00:25:00           11.543160            11.543160
#
# Tag                  240AIC022.MEAS_real  240AIC022.MEAS_visto  \
# datetime
# 2021-01-01 00:05:00             2.983948              2.983948
# 2021-01-01 00:10:00             3.015669              3.015669
# 2021-01-01 00:15:00             3.018903              3.018903
# 2021-01-01 00:20:00             3.001164              3.001164
# 2021-01-01 00:25:00             3.017393              3.017393
#
# Tag                  240AIC126.MEAS_real  240AIC126.MEAS_visto  \
# datetime
# 2021-01-01 00:05:00            11.346645             11.383555
# 2021-01-01 00:10:00            11.353215             11.409505
# 2021-01-01 00:15:00            11.355525             11.405635
# 2021-01-01 00:20:00            11.326725             11.416660
# 2021-01-01 00:25:00            11.336345             11.406170
#
# Tag                  240AIC224.MEAS_real  240AIC224.MEAS_visto  \
# datetime
# 2021-01-01 00:05:00             4.413519              4.474995
# 2021-01-01 00:10:00             4.413179              4.469886
# 2021-01-01 00:15:00             4.408321              4.481667
# 2021-01-01 00:20:00             4.408659              4.502146
# 2021-01-01 00:25:00             4.408596              4.489169
#
# Tag                  240AIC286.MEAS_real  240AIC286.MEAS_visto  ...  \
# datetime                                                        ...
# 2021-01-01 00:05:00             4.352375              4.430144  ...
# 2021-01-01 00:10:00             4.347186              4.430980  ...
# 2021-01-01 00:15:00             4.355828              4.441149  ...
# 2021-01-01 00:20:00             4.361292              4.459869  ...
# 2021-01-01 00:25:00             4.356374              4.460394  ...
#
# Tag                  S76ALE017_real  S76ALE017_visto  SSTRIPPING015_real  \
# datetime
# 2021-01-01 00:05:00           173.6            173.6               964.0
# 2021-01-01 00:10:00           173.6            173.6               964.0
# 2021-01-01 00:15:00           173.6            173.6               964.0
# 2021-01-01 00:20:00           173.6            173.6               964.0
# 2021-01-01 00:25:00           173.6            173.6               964.0
#
# Tag                  SSTRIPPING015_visto  calc_prod_d0_real  \
# datetime
# 2021-01-01 00:05:00                964.0          3240.8635
# 2021-01-01 00:10:00                964.0          3260.7475
# 2021-01-01 00:15:00                964.0          3265.5765
# 2021-01-01 00:20:00                964.0          3253.7750
# 2021-01-01 00:25:00                964.0          3236.9790
#
# Tag                  calc_prod_d0_visto  calc_prod_d1_real  \
# datetime
# 2021-01-01 00:05:00           3236.8970          3313.6215
# 2021-01-01 00:10:00           3248.4320          3301.6920
# 2021-01-01 00:15:00           3222.3990          3284.1330
# 2021-01-01 00:20:00           3235.8000          3271.9260
# 2021-01-01 00:25:00           3266.2955          3267.3050
#
# Tag                  calc_prod_d1_visto  calc_prod_p_real  calc_prod_p_visto
# datetime
# 2021-01-01 00:05:00           3236.8970         3259.3745          3236.8970
# 2021-01-01 00:10:00           3248.4320         3208.6785          3248.4320
# 2021-01-01 00:15:00           3222.3990         3210.7790          3222.3990
# 2021-01-01 00:20:00           3235.8000         3221.7745          3235.8000
# 2021-01-01 00:25:00           3266.2955         3227.6935          3266.2955
#
# [5 rows x 128 columns]
